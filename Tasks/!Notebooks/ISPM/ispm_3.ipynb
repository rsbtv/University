# %% [markdown]
# # **Задание №3. Формирование иерархической структуры проекта в контексте управления проектами информационных систем**

# %% [markdown]
# ```
# 1. ТЕОРЕТИЧЕСКИЕ ОСНОВЫ СЕГМЕНТАЦИИ ДАННЫХ ДИСТАНЦИОННОГО ЗОНДИРОВАНИЯ И АРХИТЕКТУР С ГЛОБАЛЬНЫМ РЕЦЕПТИВНЫМ ПОЛЕМ
#    1.1. Данные дистанционного зондирования и постановка задачи сегментации
#    	  1.1.1. Классы данных ДЗЗ и их характеристики
#    	  1.1.2. Особенности сегментации сцен ДЗЗ
#    	  1.1.3. Метрики качества сегментации для данных ДЗЗ
#    1.2. Свёрточные и трансформерные архитектуры с глобальным контекстом
#    	  1.2.1. Классические свёрточные сети для сегментации
#    	  1.2.2. Архитектуры с расширенным рецептивным полем и крупными ядрами
#    	  1.2.3. Трансформеры и гибридные модели для сегментации
#    1.3. Архитектура HyenaPixel и неявное моделирование фильтров
#    	  1.3.1. Оператор Hyena и иерархия неявных свёрточных фильтров
#    	  1.3.2. HyenaPixel как архитектура с глобальным рецептивным полем для изображений
#    	  1.3.3. Потенциал HyenaPixel для задач сегментации данных ДЗЗ
#
# 2. АНАЛИТИЧЕСКОЕ ОБОСНОВАНИЕ МЕТОДИКИ СЕГМЕНТАЦИИ И ФОРМИРОВАНИЕ ТРЕБОВАНИЙ
#    2.1. Анализ существующих методов сегментации данных ДЗЗ
#    	  2.1.1. Свёрточные модели для сегментации спутниковых изображений
#    	  2.1.2. Модели на основе внимания и глобального контекста
#    	  2.1.3. Ограничения и пробелы существующих решений
#    2.2. Формирование требований к методике сегментации на основе HyenaPixel
#    	  2.2.1. Функциональные требования и целевые сценарии применения
#    	  2.2.2. Требования к качеству, устойчивости и обобщающей способности
#    	  2.2.3. Требования к вычислительной эффективности и инференсу
#    2.3. Концепция методики с самоконтролируемым обучением и неявным моделированием фильтров
#    	  2.3.1. Использование самоконтролируемого обучения на данных ДЗЗ
#    	  2.3.2. Интеграция предварительного обучения и дообучения для сегментации
#    	  2.3.3. Формулировка гипотез и план экспериментов
#
# 3. ПРОЕКТИРОВАНИЕ, РЕАЛИЗАЦИЯ И ОЦЕНКА МЕТОДИКИ СЕГМЕНТАЦИИ НА ОСНОВЕ HYENAPIXEL
#    3.1. Проектирование архитектуры сегментационной модели на основе HyenaPixel
#    	  3.1.1. Адаптация HyenaPixel к сегментационной постановке
#    	  3.1.2. Интеграция механизма неявных фильтров в архитектуру сегментации
#    	  3.1.3. Проектирование обучающего конвейера и обработки данных
#    3.2. Оптимизация инференса и внедрение в вычислительную инфраструктуру
#    	  3.2.1. Профилирование модели и выявление узких мест
#    	  3.2.2. Методы оптимизации и компрессии модели
#    	  3.2.3. Развёртывание и интеграция в практические сценарии
#    3.3. Экспериментальная оценка качества и эффективности методики
#    	  3.3.1. Описание наборов данных и протокола экспериментов
#    	  3.3.2. Количественная оценка качества сегментации и скорости инференса
#    	  3.3.3. Анализ ошибок, абляционные исследования и направления дальнейшего развития
# ```
